# %% [markdown]
# <h1> TEST</h1>

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# <h1> DOWNLOAD Libraries</h1>

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h1>IMPORTANT DATASET TO DATA FRAME</h1>

# %%
penguins = pd.read_csv('datasets\\penguins.csv')

# %%
penguins
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %% [markdown]
# <h1> Checking your DATA FRAME for null values, and data types</h1>

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %%
penguins.isnull()
# Out:
#      rowid  species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    False    False   False           False          False              False
# 1    False    False   False           False          False              False
# 2    False    False   False           False          False              False
# 3    False    False   False            True           True               True
# 4    False    False   False           False          False              False
# ..     ...      ...     ...             ...            ...                ...
# 339  False    False   False           False          False              False
# 340  False    False   False           False          False              False
# 341  False    False   False           False          False              False
# 342  False    False   False           False          False              False
# 343  False    False   False           False          False              False
#
#      body_mass_g    sex   year
# ...

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# <h1>DESCRIPTIVE ANALYTICS</h1>

# %%
penguins.describe()
# Out:
#             rowid  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   172.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      1.000000       32.100000      13.100000         172.000000
# 25%     86.750000       39.225000      15.600000         190.000000
# 50%    172.500000       44.450000      17.300000         197.000000
# 75%    258.250000       48.500000      18.700000         213.000000
# max    344.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   342.000000   344.000000
# mean   4201.754386  2008.029070
# std     801.954536     0.818356
# min    2700.000000  2007.000000
# 25%    3550.000000  2007.000000
# 50%    4050.000000  2008.000000
# 75%    4750.000000  2009.000000
# max    6300.000000  2009.000000

# %%
#to flip the describe table

# %%
penguins.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# rowid              344.0   172.500000   99.448479     1.0    86.750   172.50
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
# year               344.0  2008.029070    0.818356  2007.0  2007.000  2008.00
#
#                        75%     max
# rowid               258.25   344.0
# bill_length_mm       48.50    59.6
# bill_depth_mm        18.70    21.5
# flipper_length_mm   213.00   231.0
# body_mass_g        4750.00  6300.0
# year               2009.00  2009.0

# %% [markdown]
# <h1>FILTERING DATA BASED FROM COLUMNS</h1>

# %%
penguins['body_mass_g']
# Out:
# 0      3750.0
# 1      3800.0
# 2      3250.0
# 3         NaN
# 4      3450.0
#         ...
# 339    4000.0
# 340    3400.0
# 341    3775.0
# 342    4100.0
# 343    3775.0
# Name: body_mass_g, Length: 344, dtype: float64

# %% [markdown]
# <h1>HOW TO DEFINE/ CREATE YOUR OWN COLUMN</h1>

# %%
penguins['weight']= np.round(penguins['body_mass_g'] / 1000,2)

# %%
penguins
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0                181.0       3750.0    male  2007    3.75
# 1                186.0       3800.0  female  2007    3.80
# ...

# %%
penguins
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  weight
# 0                181.0       3750.0    male  2007    3.75
# 1                186.0       3800.0  female  2007    3.80
# ...

# %% [markdown]
# <h1>WHAT TO DO WITH NULL VALUES</h1>

# %% [markdown]
# delete the row
#
# fill the empty cells with a value

# %%
penguins['body_mass_g'].mean()
# Out:
# np.float64(4201.754385964912)

# %%
penguins['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %%
penguins['bill_length_mm'] = penguins['bill_length_mm'].fillna(penguins['bill_length_mm'].mean())

# %%
penguins['body_mass_g'] = penguins['body_mass_g'].fillna(penguins['body_mass_g'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           0
# sex                  11
# year                  0
# weight                2
# dtype: int64

# %%
penguins['sex'] = penguins['sex'].fillna(penguins['sex'].mode()[0])

# %%
penguins.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        2
# flipper_length_mm    2
# body_mass_g          0
# sex                  0
# year                 0
# weight               2
# dtype: int64

# %%
penguins['bill_depth_mm'] = penguins['bill_depth_mm'].fillna(penguins['bill_depth_mm'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    2
# body_mass_g          0
# sex                  0
# year                 0
# weight               2
# dtype: int64

# %%
penguins['flipper_length_mm'] = penguins['flipper_length_mm'].fillna(penguins['flipper_length_mm'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               2
# dtype: int64

# %%
penguins['weight'] = penguins['weight'].fillna(penguins['weight'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               0
# dtype: int64

# %%
penguins
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000       18.70000
# 1        2     Adelie  Torgersen        39.50000       17.40000
# 2        3     Adelie  Torgersen        40.30000       18.00000
# 3        4     Adelie  Torgersen        43.92193       17.15117
# 4        5     Adelie  Torgersen        36.70000       19.30000
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream        55.80000       19.80000
# 340    341  Chinstrap      Dream        43.50000       18.10000
# 341    342  Chinstrap      Dream        49.60000       18.20000
# 342    343  Chinstrap      Dream        50.80000       19.00000
# 343    344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year    weight
# 0           181.000000  3750.000000    male  2007  3.750000
# 1           186.000000  3800.000000  female  2007  3.800000
# ...

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    object
#  8   year               344 non-null    int64
#  9   weight             344 non-null    float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 27.0+ KB

# %%
penguins['year'] = penguins['year'].astype('category')

# %%
penguins['species'] = penguins['species'].astype('category')

# %%
penguins['rowid'] = penguins['rowid'].astype('category')

# %%
penguins['island'] = penguins['island'].astype('category')

# %%
penguins['sex'] = penguins['sex'].astype('category')

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    category
#  1   species            344 non-null    category
#  2   island             344 non-null    category
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    category
#  8   year               344 non-null    category
#  9   weight             344 non-null    float64
# dtypes: category(5), float64(5)
# memory usage: 26.9 KB

# %%
penguins['species'] == "Chinstrap"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Name: species, Length: 344, dtype: bool

# %%
penguins[penguins['species'] == "Chinstrap"].count()
# Out:
# rowid                68
# species              68
# island               68
# bill_length_mm       68
# bill_depth_mm        68
# flipper_length_mm    68
# body_mass_g          68
# sex                  68
# year                 68
# weight               68
# dtype: int64

# %%
penguins[penguins['species'] == "Adelie"].count()
# Out:
# rowid                152
# species              152
# island               152
# bill_length_mm       152
# bill_depth_mm        152
# flipper_length_mm    152
# body_mass_g          152
# sex                  152
# year                 152
# weight               152
# dtype: int64

# %%
penguins[penguins['species'] == "Gentoo"].count()
# Out:
# rowid                124
# species              124
# island               124
# bill_length_mm       124
# bill_depth_mm        124
# flipper_length_mm    124
# body_mass_g          124
# sex                  124
# year                 124
# weight               124
# dtype: int64

# %% [markdown]
# <h1>HOW MANY GENTOO SPECIES GAVE WEIGHT MORE THAN 3KG</h1>

# %%
penguins[penguins['species'] == "Gentoo"]
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152   153  Gentoo  Biscoe        46.10000       13.20000         211.000000
# 153   154  Gentoo  Biscoe        50.00000       16.30000         230.000000
# 154   155  Gentoo  Biscoe        48.70000       14.10000         210.000000
# 155   156  Gentoo  Biscoe        50.00000       15.20000         218.000000
# 156   157  Gentoo  Biscoe        47.60000       14.50000         215.000000
# ..    ...     ...     ...             ...            ...                ...
# 271   272  Gentoo  Biscoe        43.92193       17.15117         200.915205
# 272   273  Gentoo  Biscoe        46.80000       14.30000         215.000000
# 273   274  Gentoo  Biscoe        50.40000       15.70000         222.000000
# 274   275  Gentoo  Biscoe        45.20000       14.80000         212.000000
# 275   276  Gentoo  Biscoe        49.90000       16.10000         213.000000
#
#      body_mass_g     sex  year    weight
# ...

# %%
penguins[penguins['weight'] > 3].count()
# Out:
# rowid                333
# species              333
# island               333
# bill_length_mm       333
# bill_depth_mm        333
# flipper_length_mm    333
# body_mass_g          333
# sex                  333
# year                 333
# weight               333
# dtype: int64

# %%
penguins[(penguins['species'] == "Gentoo") & (penguins['weight'] > 3)]
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152   153  Gentoo  Biscoe        46.10000       13.20000         211.000000
# 153   154  Gentoo  Biscoe        50.00000       16.30000         230.000000
# 154   155  Gentoo  Biscoe        48.70000       14.10000         210.000000
# 155   156  Gentoo  Biscoe        50.00000       15.20000         218.000000
# 156   157  Gentoo  Biscoe        47.60000       14.50000         215.000000
# ..    ...     ...     ...             ...            ...                ...
# 271   272  Gentoo  Biscoe        43.92193       17.15117         200.915205
# 272   273  Gentoo  Biscoe        46.80000       14.30000         215.000000
# 273   274  Gentoo  Biscoe        50.40000       15.70000         222.000000
# 274   275  Gentoo  Biscoe        45.20000       14.80000         212.000000
# 275   276  Gentoo  Biscoe        49.90000       16.10000         213.000000
#
#      body_mass_g     sex  year    weight
# ...

# %% [markdown]
# <h1>HOW MANY GENTOO SPECIES GAVE WEIGHT MORE THAN 3KG</h1>

# %%
penguins[(penguins['species'] == "Gentoo") & (penguins['weight'] < 3)].count()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               0
# dtype: int64

# %% [markdown]
# <h1>Does Gentoo exclusively live on just one ISLAND</h1>

# %%
penguins['species'] == "Gentoo"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
penguins[penguins['species'] == "Gentoo"]
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152   153  Gentoo  Biscoe        46.10000       13.20000         211.000000
# 153   154  Gentoo  Biscoe        50.00000       16.30000         230.000000
# 154   155  Gentoo  Biscoe        48.70000       14.10000         210.000000
# 155   156  Gentoo  Biscoe        50.00000       15.20000         218.000000
# 156   157  Gentoo  Biscoe        47.60000       14.50000         215.000000
# ..    ...     ...     ...             ...            ...                ...
# 271   272  Gentoo  Biscoe        43.92193       17.15117         200.915205
# 272   273  Gentoo  Biscoe        46.80000       14.30000         215.000000
# 273   274  Gentoo  Biscoe        50.40000       15.70000         222.000000
# 274   275  Gentoo  Biscoe        45.20000       14.80000         212.000000
# 275   276  Gentoo  Biscoe        49.90000       16.10000         213.000000
#
#      body_mass_g     sex  year    weight
# ...

# %% [markdown]
# <h1>
#     GENTOO IN BISCOE ISLAND
# </h1>

# %%
gentoo_biscoe = penguins[(penguins['island'] == "Biscoe") & (penguins['species'] == "Gentoo")]

# %%
gentoo_biscoe
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152   153  Gentoo  Biscoe        46.10000       13.20000         211.000000
# 153   154  Gentoo  Biscoe        50.00000       16.30000         230.000000
# 154   155  Gentoo  Biscoe        48.70000       14.10000         210.000000
# 155   156  Gentoo  Biscoe        50.00000       15.20000         218.000000
# 156   157  Gentoo  Biscoe        47.60000       14.50000         215.000000
# ..    ...     ...     ...             ...            ...                ...
# 271   272  Gentoo  Biscoe        43.92193       17.15117         200.915205
# 272   273  Gentoo  Biscoe        46.80000       14.30000         215.000000
# 273   274  Gentoo  Biscoe        50.40000       15.70000         222.000000
# 274   275  Gentoo  Biscoe        45.20000       14.80000         212.000000
# 275   276  Gentoo  Biscoe        49.90000       16.10000         213.000000
#
#      body_mass_g     sex  year    weight
# ...

# %%
penguins[(penguins['species'] == "Gentoo") & (penguins['island'] == "Biscoe")].count()
# Out:
# rowid                124
# species              124
# island               124
# bill_length_mm       124
# bill_depth_mm        124
# flipper_length_mm    124
# body_mass_g          124
# sex                  124
# year                 124
# weight               124
# dtype: int64

# %% [markdown]
# <h1>
#     GENTOO IN DREAM ISLAND
# </h1>

# %%
gentoo_dream = penguins[(penguins['island'] == "Dream") & (penguins['species'] == "Gentoo")]

# %%
gentoo_dream
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight]
# Index: []

# %%
penguins[(penguins['species'] == "Gentoo") & (penguins['island'] == "Dream")].count()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               0
# dtype: int64

# %% [markdown]
# <h1>
#     GENTOO IN Torgersen ISLAND
# </h1>

# %%
gentoo_torgersen = penguins[(penguins['island'] == "Torgersen") & (penguins['species'] == "Gentoo")]

# %%
gentoo_torgersen
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight]
# Index: []

# %%
penguins[(penguins['species'] == "Gentoo") & (penguins['island'] == "Dream")].count()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               0
# dtype: int64

# %% [markdown]
# <h1>INSIGHT NO.1</h1>
#
# <H3> GENTOO IS EXCLUSIVLY LIVE IN BISCOE</H3>

# %% [markdown]
# <h1>
#     ADELIE IN BISCOE ISLAND
# </h1>

# %%
adelie_Biscoe = penguins[(penguins['island'] == "Biscoe") & (penguins['species'] == "Adelie")]

# %%
adelie_Biscoe
# Out:
#     rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20     21  Adelie  Biscoe            37.8           18.3              174.0
# 21     22  Adelie  Biscoe            37.7           18.7              180.0
# 22     23  Adelie  Biscoe            35.9           19.2              189.0
# 23     24  Adelie  Biscoe            38.2           18.1              185.0
# 24     25  Adelie  Biscoe            38.8           17.2              180.0
# 25     26  Adelie  Biscoe            35.3           18.9              187.0
# 26     27  Adelie  Biscoe            40.6           18.6              183.0
# 27     28  Adelie  Biscoe            40.5           17.9              187.0
# 28     29  Adelie  Biscoe            37.9           18.6              172.0
# 29     30  Adelie  Biscoe            40.5           18.9              180.0
# 50     51  Adelie  Biscoe            39.6           17.7              186.0
# ...

# %%
penguins[(penguins['species'] == "Adelie") & (penguins['island'] == "Biscoe")].count()
# Out:
# rowid                44
# species              44
# island               44
# bill_length_mm       44
# bill_depth_mm        44
# flipper_length_mm    44
# body_mass_g          44
# sex                  44
# year                 44
# weight               44
# dtype: int64

# %% [markdown]
# <h1>
#     ADELIE IN DREAM ISLAND
# </h1>

# %%
adelie_dream = penguins[(penguins['island'] == "Dream") & (penguins['species'] == "Adelie")]

# %%
adelie_dream
# Out:
#     rowid species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30     31  Adelie  Dream            39.5           16.7              178.0
# 31     32  Adelie  Dream            37.2           18.1              178.0
# 32     33  Adelie  Dream            39.5           17.8              188.0
# 33     34  Adelie  Dream            40.9           18.9              184.0
# 34     35  Adelie  Dream            36.4           17.0              195.0
# 35     36  Adelie  Dream            39.2           21.1              196.0
# 36     37  Adelie  Dream            38.8           20.0              190.0
# 37     38  Adelie  Dream            42.2           18.5              180.0
# 38     39  Adelie  Dream            37.6           19.3              181.0
# 39     40  Adelie  Dream            39.8           19.1              184.0
# 40     41  Adelie  Dream            36.5           18.0              182.0
# ...

# %%
penguins[(penguins['species'] == "Adelie") & (penguins['island'] == "Dream")].count()
# Out:
# rowid                56
# species              56
# island               56
# bill_length_mm       56
# bill_depth_mm        56
# flipper_length_mm    56
# body_mass_g          56
# sex                  56
# year                 56
# weight               56
# dtype: int64

# %% [markdown]
# <h1>
#     ADELIE IN TORGERSEN ISLAND
# </h1>

# %%
adelie_torgersen = penguins[(penguins['island'] == "Torgersen") & (penguins['species'] == "Adelie")]

# %%
adelie_torgersen
# Out:
#     rowid species     island  bill_length_mm  bill_depth_mm  \
# 0       1  Adelie  Torgersen        39.10000       18.70000
# 1       2  Adelie  Torgersen        39.50000       17.40000
# 2       3  Adelie  Torgersen        40.30000       18.00000
# 3       4  Adelie  Torgersen        43.92193       17.15117
# 4       5  Adelie  Torgersen        36.70000       19.30000
# 5       6  Adelie  Torgersen        39.30000       20.60000
# 6       7  Adelie  Torgersen        38.90000       17.80000
# 7       8  Adelie  Torgersen        39.20000       19.60000
# 8       9  Adelie  Torgersen        34.10000       18.10000
# 9      10  Adelie  Torgersen        42.00000       20.20000
# 10     11  Adelie  Torgersen        37.80000       17.10000
# 11     12  Adelie  Torgersen        37.80000       17.30000
# 12     13  Adelie  Torgersen        41.10000       17.60000
# 13     14  Adelie  Torgersen        38.60000       21.20000
# 14     15  Adelie  Torgersen        34.60000       21.10000
# ...

# %%
penguins[(penguins['species'] == "Adelie") & (penguins['island'] == "Torgersen")].count()
# Out:
# rowid                52
# species              52
# island               52
# bill_length_mm       52
# bill_depth_mm        52
# flipper_length_mm    52
# body_mass_g          52
# sex                  52
# year                 52
# weight               52
# dtype: int64

# %% [markdown]
# <h1>INSIGHT NO.2</h1>
#
# <H3> ADELIE LIVES IN 3 ISLAND</H3>

# %%
chinstrap_biscoe = penguins[(penguins['island'] == "Biscoe") & (penguins['species'] == "Chinstrap")]

# %%
chinstrap_biscoe
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight]
# Index: []

# %%
penguins[(penguins['species'] == "Chinstrap") & (penguins['island'] == "Biscoe")].count()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               0
# dtype: int64

# %%
chinstrap_dream = penguins[(penguins['island'] == "Dream") & (penguins['species'] == "Chinstrap")]

# %%
chinstrap_dream
# Out:
#     rowid    species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276   277  Chinstrap  Dream            46.5           17.9              192.0
# 277   278  Chinstrap  Dream            50.0           19.5              196.0
# 278   279  Chinstrap  Dream            51.3           19.2              193.0
# 279   280  Chinstrap  Dream            45.4           18.7              188.0
# 280   281  Chinstrap  Dream            52.7           19.8              197.0
# ..    ...        ...    ...             ...            ...                ...
# 339   340  Chinstrap  Dream            55.8           19.8              207.0
# 340   341  Chinstrap  Dream            43.5           18.1              202.0
# 341   342  Chinstrap  Dream            49.6           18.2              193.0
# 342   343  Chinstrap  Dream            50.8           19.0              210.0
# 343   344  Chinstrap  Dream            50.2           18.7              198.0
#
# ...

# %%
penguins[(penguins['species'] == "Chinstrap") & (penguins['island'] == "Dream")].count()
# Out:
# rowid                68
# species              68
# island               68
# bill_length_mm       68
# bill_depth_mm        68
# flipper_length_mm    68
# body_mass_g          68
# sex                  68
# year                 68
# weight               68
# dtype: int64

# %%
chinstrap_torgersen = penguins[(penguins['island'] == "Torgersen") & (penguins['species'] == "Chinstrap")]

# %%
chinstrap_torgersen
# Out:
# Empty DataFrame
# Columns: [rowid, species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, sex, year, weight]
# Index: []

# %%
penguins[(penguins['species'] == "Chinstrap") & (penguins['island'] == "Torgersen")].count()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# weight               0
# dtype: int64

# %% [markdown]
# <h1>INSIGHT NO.3</h1>
#
# <H3> CHINSTRAP EXCLUSIVELY DREAM ISLAND</H3>

# %%
penguins
# Out:
#     rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0       1     Adelie  Torgersen        39.10000       18.70000
# 1       2     Adelie  Torgersen        39.50000       17.40000
# 2       3     Adelie  Torgersen        40.30000       18.00000
# 3       4     Adelie  Torgersen        43.92193       17.15117
# 4       5     Adelie  Torgersen        36.70000       19.30000
# ..    ...        ...        ...             ...            ...
# 339   340  Chinstrap      Dream        55.80000       19.80000
# 340   341  Chinstrap      Dream        43.50000       18.10000
# 341   342  Chinstrap      Dream        49.60000       18.20000
# 342   343  Chinstrap      Dream        50.80000       19.00000
# 343   344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year    weight
# 0           181.000000  3750.000000    male  2007  3.750000
# 1           186.000000  3800.000000  female  2007  3.800000
# ...

# %% [markdown]
# <h1>INSIGHT NO.4</h1>
#
# <H3> THE ISLAND DOES NOT IMPACT THE WEIGHT OF SPECIE ADELIE</H3>

# %% [markdown]
# <h1>ADELIE</h1>

# %%
adelie_Biscoe_w = np.round(adelie_Biscoe['weight'].mean(),1)

# %%
adelie_Biscoe_w
# Out:
# np.float64(3.7)

# %%
adelie_dream_w = np.round(adelie_dream['weight'].mean(),1)

# %%
adelie_dream_w
# Out:
# np.float64(3.7)

# %%
adelie_torgersen_w = np.round(adelie_torgersen['weight'].mean(),1)

# %%
adelie_torgersen_w
# Out:
# np.float64(3.7)

# %% [markdown]
# <h1>INSIGHT NO.5</h1>
#
# <H3> IMPACT WEIGHT</H3>

# %% [markdown]
# <h1>Gentoo</h1>

# %%
gentoo_biscoe_w = np.round(gentoo_biscoe['weight'].mean(),1)

# %%
gentoo_biscoe_w
# Out:
# np.float64(5.1)

# %%
gentoo_dream_w = np.round(gentoo_dream['weight'].mean(),1)

# %%
gentoo_dream_w
# Out:
# np.float64(nan)

# %%
gentoo_torgersen_w = np.round(gentoo_torgersen['weight'].mean(),1)

# %%
gentoo_torgersen_w
# Out:
# np.float64(nan)

# %% [markdown]
# <h1>INSIGHT NO.6</h1>
#
# <H3> IMPACT WEIGHT</H3>

# %% [markdown]
# <h1>Chinstrap</h1>

# %%
chinstrap_biscoe_w = np.round(chinstrap_biscoe['weight'].mean(),1)

# %%
chinstrap_biscoe_w
# Out:
# np.float64(nan)

# %%
chinstrap_dream_w = np.round(chinstrap_dream['weight'].mean(),1)

# %%
chinstrap_dream_w
# Out:
# np.float64(3.7)

# %%
chinstrap_torgersen_w = np.round(chinstrap_torgersen['weight'].mean(),1)

# %%
chinstrap_torgersen_w
# Out:
# np.float64(nan)

# %% [markdown]
# <h1>INSIGHT NO.7</h1>
#
# <H3> THE HEVIEST SPECIE IS GENTOO</H3>

# %% [markdown]
# <h1> HOW TO USE GROUPBY</h1>
#
# <ol>
#     <li> NAME THE GROUP BY REFERENCE DATA FRAME</li>
#     <li>Call the dataframe</li>
#     <li>.groupby function </li>
#     <li>columns to group </li>
#     <li>group by gunction </li>
# </ol>

# %%
penguins
# Out:
#     rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0       1     Adelie  Torgersen        39.10000       18.70000
# 1       2     Adelie  Torgersen        39.50000       17.40000
# 2       3     Adelie  Torgersen        40.30000       18.00000
# 3       4     Adelie  Torgersen        43.92193       17.15117
# 4       5     Adelie  Torgersen        36.70000       19.30000
# ..    ...        ...        ...             ...            ...
# 339   340  Chinstrap      Dream        55.80000       19.80000
# 340   341  Chinstrap      Dream        43.50000       18.10000
# 341   342  Chinstrap      Dream        49.60000       18.20000
# 342   343  Chinstrap      Dream        50.80000       19.00000
# 343   344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year    weight
# 0           181.000000  3750.000000    male  2007  3.750000
# 1           186.000000  3800.000000  female  2007  3.800000
# ...

# %%
penguins_agg = penguins.groupby(['species','sex','island','year']).size()
# Out:
# C:\Users\LAB4-StudentPC04\AppData\Local\Temp\ipykernel_7304\3861779661.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   penguins_agg = penguins.groupby(['species','sex','island','year']).size()

# %%
penguins_agg.unstack()
# Out:
# year                        2007  2008  2009
# species   sex    island
# Adelie    female Biscoe        5     9     8
#                  Dream         9     8    10
#                  Torgersen     8     8     8
#           male   Biscoe        5     9     8
#                  Dream        11     8    10
#                  Torgersen    12     8     8
# Chinstrap female Biscoe        0     0     0
#                  Dream        13     9    12
#                  Torgersen     0     0     0
#           male   Biscoe        0     0     0
#                  Dream        13     9    12
#                  Torgersen     0     0     0
# Gentoo    female Biscoe       16    22    20
#                  Dream         0     0     0
#                  Torgersen     0     0     0
#           male   Biscoe       18    24    24
#                  Dream         0     0     0
#                  Torgersen     0     0     0

# %% [markdown]
# <h1>INSIGHT NO.8</h1>
#
# <H3> THE HIGHEST RECORDED MALE ADELIE IS IN TORGERSEN</H3>

# %%
penguins_agg2 = np.round(penguins.groupby(['species','sex','island',])['weight'].mean(),2)
# Out:
# C:\Users\LAB4-StudentPC04\AppData\Local\Temp\ipykernel_7304\4263053565.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   penguins_agg2 = np.round(penguins.groupby(['species','sex','island',])['weight'].mean(),2)

# %%
penguins_agg3 = np.round(penguins.groupby(['species','sex'])['weight'].mean(),2)
# Out:
# C:\Users\LAB4-StudentPC04\AppData\Local\Temp\ipykernel_7304\3375569794.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   penguins_agg3 = np.round(penguins.groupby(['species','sex'])['weight'].mean(),2)

# %%
penguins_agg2.unstack()
# Out:
# island            Biscoe  Dream  Torgersen
# species   sex
# Adelie    female    3.37   3.34       3.40
#           male      4.05   4.01       3.99
# Chinstrap female     NaN   3.53        NaN
#           male       NaN   3.94        NaN
# Gentoo    female    4.68    NaN        NaN
#           male      5.41    NaN        NaN

# %%
penguins_agg3.unstack()
# Out:
# sex        female  male
# species
# Adelie       3.37  4.01
# Chinstrap    3.53  3.94
# Gentoo       4.68  5.41

# %% [markdown]
# <h1>INSIGHT NO.9</h1>
#
# <H3> THE AGERAGE WEIGHT FOR ADELIE: </H3>
# <H4>MALE: 4.01</H4>
# <H4>FEMALE: 3.37</H4>

# %% [markdown]
# <h1>INSIGHT NO.10</h1>
#
# <H3> THE AGERAGE WEIGHT FOR Chinstrap: </H3>
# <H4>MALE: 3.94</H4>
# <H4>FEMALE: 3.53</H4>

# %% [markdown]
# <h1>INSIGHT NO.11</h1>
#
# <H3> THE AGERAGE WEIGHT FOR Gentoo: </H3>
# <H4>MALE: 4.68</H4>
# <H4>FEMALE: 5.41</H4>

# %% [markdown]
# <h1>DOES THE BILL LENGHT AFFECTS THE SIZE OF THE DEPTH</h1>

# %%
b_dept_lenght_cor = penguins['bill_length_mm'].corr(penguins['bill_depth_mm'])

# %%
b_dept_lenght_cor
# Out:
# np.float64(-0.23505287035553282)

# %% [markdown]
# <h1>INSIGHT NO. 12</h1>
#
# <H3>BILL LENGHT HAS NO COORELATION WITH BILL DEPTH</H3>

# %% [markdown]
# <h1>DOES THE BILL LENGTH AFFECTS THE BODY MASS</h1>

# %%
blenght_body_cor = penguins['bill_length_mm'].corr(penguins['body_mass_g'])

# %%
blenght_body_cor
# Out:
# np.float64(0.5951098244376304)

# %% [markdown]
# <h1>INSIGHT NO. 13</h1>
#
# <H3>BILL LENGHT HAS COORELATION WITH BODY MASS</H3>

# %% [markdown]
# <h1>DOES THE FLIPPER LENGTH AFFECTS THE BODY MASS</h1>

# %%
flenght_body_cor = penguins['flipper_length_mm'].corr(penguins['body_mass_g'])

# %%
flenght_body_cor
# Out:
# np.float64(0.8712017673060114)

# %% [markdown]
# <h1>INSIGHT NO. 14</h1>
#
# <H3>FLIPPER LENGHT HAS COORELATION WITH BODY MASS</H3>

# %% [markdown]
# <h1>DOES THE FLIPPER AFFECTS THE BILL LENGTH</h1>

# %%
flenght_billlegnth_cor = penguins['flipper_length_mm'].corr(penguins['bill_length_mm'])

# %%
flenght_billlegnth_cor
# Out:
# np.float64(0.6561813407464278)

# %% [markdown]
# <h1>INSIGHT NO. 15</h1>
#
# <H3>FLIPPER LENGHT HAS COORELATION WITH BILL LENGTH</H3>

# %% [markdown]
# <h1>CORRELATION BETWEEN QUALITATIVE AND QUANTITATIVE</h1>
#
# <H3>SEX AND BODY MASS</H3>

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy.stats import f_oneway

# %% [markdown]
# <h3> requirements for one way annova </h3>
# <h3> filter columns and its data </h3>

# %%
penguins[penguins['sex'] == 'male']['body_mass_g']
# Out:
# 0      3750.000000
# 3      4201.754386
# 5      3650.000000
# 7      4675.000000
# 8      3475.000000
#           ...
# 334    3800.000000
# 336    3950.000000
# 339    4000.000000
# 341    3775.000000
# 342    4100.000000
# Name: body_mass_g, Length: 179, dtype: float64

# %%
penguins[penguins['sex'] == 'female']['body_mass_g']
# Out:
# 1      3800.0
# 2      3250.0
# 4      3450.0
# 6      3625.0
# 12     3200.0
#         ...
# 335    3525.0
# 337    3650.0
# 338    3650.0
# 340    3400.0
# 343    3775.0
# Name: body_mass_g, Length: 165, dtype: float64

# %%
f_oneway(penguins[penguins['sex'] == 'male']['body_mass_g'],penguins[penguins['sex'] == 'female']['body_mass_g'])
# Out:
# F_onewayResult(statistic=np.float64(68.38476171974526), pvalue=np.float64(3.0226600487050246e-15))

# %%
f_stats, p_value =  f_oneway(penguins[penguins['sex'] == 'male']['body_mass_g'],penguins[penguins['sex'] == 'female']['body_mass_g'])

# %%
f_stats
# Out:
# np.float64(68.38476171974526)

# %%
p_value
# Out:
# np.float64(3.0226600487050246e-15)

# %% [markdown]
# <h1>INSIGHT NO. 16</h1>
#
# <H3>THERE IS A CORRELATION BETWEEN SEX AND BODY MASS</H3>

# %%
penguins
# Out:
#     rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0       1     Adelie  Torgersen        39.10000       18.70000
# 1       2     Adelie  Torgersen        39.50000       17.40000
# 2       3     Adelie  Torgersen        40.30000       18.00000
# 3       4     Adelie  Torgersen        43.92193       17.15117
# 4       5     Adelie  Torgersen        36.70000       19.30000
# ..    ...        ...        ...             ...            ...
# 339   340  Chinstrap      Dream        55.80000       19.80000
# 340   341  Chinstrap      Dream        43.50000       18.10000
# 341   342  Chinstrap      Dream        49.60000       18.20000
# 342   343  Chinstrap      Dream        50.80000       19.00000
# 343   344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year    weight
# 0           181.000000  3750.000000    male  2007  3.750000
# 1           186.000000  3800.000000  female  2007  3.800000
# ...

# %%
penguins[penguins['species'] == 'Adelie']['body_mass_g']
# Out:
# 0      3750.000000
# 1      3800.000000
# 2      3250.000000
# 3      4201.754386
# 4      3450.000000
#           ...
# 147    3475.000000
# 148    3450.000000
# 149    3750.000000
# 150    3700.000000
# 151    4000.000000
# Name: body_mass_g, Length: 152, dtype: float64

# %%
penguins[penguins['species'] == 'Gentoo']['body_mass_g']
# Out:
# 152    4500.000000
# 153    5700.000000
# 154    4450.000000
# 155    5700.000000
# 156    5400.000000
#           ...
# 271    4201.754386
# 272    4850.000000
# 273    5750.000000
# 274    5200.000000
# 275    5400.000000
# Name: body_mass_g, Length: 124, dtype: float64

# %%
penguins[penguins['species'] == 'Chinstrap']['body_mass_g']
# Out:
# 276    3500.0
# 277    3900.0
# 278    3650.0
# 279    3525.0
# 280    3725.0
#         ...
# 339    4000.0
# 340    3400.0
# 341    3775.0
# 342    4100.0
# 343    3775.0
# Name: body_mass_g, Length: 68, dtype: float64

# %%
f_stats_species, p_value_species =  f_oneway(penguins[penguins['species'] == 'Adelie']['body_mass_g'],
                                             penguins[penguins['species'] == 'Gentoo']['body_mass_g'],
                                            penguins[penguins['species'] == 'Chinstrap']['body_mass_g'])

# %%
f_stats_species
# Out:
# np.float64(338.5729100782222)

# %%
p_value_species
# Out:
# np.float64(1.0069770504490335e-81)
